# %%
import numpy as np
import pandas as pd

# %%
s1 = pd.Series([1, 2, 3], index=['a', 'b', 'c']) # 通过数组
s2 = pd.Series({'a':1, 'b':2, 'c':3}) # 通过字典
print(s1.iloc[0])

# %%
print(s1.loc['a'])
print(s1.loc['a':'c'])

# %%
s = pd.Series({'a': 4, 'b': 7, 'c': -5, 'd': 3}, index=['a', 'c'], name='filtered')
print(s)
# Out:
# a    4
# c   -5
# Name: filtered, dtype: int64
