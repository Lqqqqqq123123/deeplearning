# %%
import numpy as np
arr1 = np.random.randn(2, 3, 3)

# %%
print(arr1.shape)
print(arr1.ndim)
print(arr1.itemsize)
print(arr1.dtype)
print(arr1.nbytes)
print(arr1.size)
# Out:
# (2, 3, 3)
# 3
# 8
# float64
# 144
# 18
